# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from plotly import express as px
import numpy as np
eth = pd.read_csv('home_value_by_zipcode.csv')
eth.head()
eth1 = eth[eth['State']=='CA']
eth1[eth1['City']=='San Francisco']
# Out:
#        RegionID  SizeRank  RegionName RegionType StateName State  \
# 13        97564        13       94109        Zip        CA    CA
# 93        97565        94       94110        Zip        CA    CA
# 389       97576       391       94122        Zip        CA    CA
# 588       97567       592       94112        Zip        CA    CA
# 859       97569       864       94115        Zip        CA    CA
# 1008      97571      1015       94117        Zip        CA    CA
# 1034      97557      1041       94102        Zip        CA    CA
# 1054      97575      1062       94121        Zip        CA    CA
# 1244      97572      1254       94118        Zip        CA    CA
# 1389      97558      1401       94103        Zip        CA    CA
# 1395      97568      1408       94114        Zip        CA    CA
# 1451      97562      1463       94107        Zip        CA    CA
# 2057      97570      2073       94116        Zip        CA    CA
# ...

# %%
crime = pd.read_csv('crime&population_density.csv')
joint1= pd.merge(eth1,crime,how = "inner",left_on=["City"],right_on=["City/Agency"])
joint1
#joint.groupby(['Place']).head()
# Out:
#       RegionID  SizeRank  RegionName RegionType StateName State  \
# 0        97564        13       94109        Zip        CA    CA
# 1        97565        94       94110        Zip        CA    CA
# 2        97576       391       94122        Zip        CA    CA
# 3        97567       592       94112        Zip        CA    CA
# 4        97569       864       94115        Zip        CA    CA
# ...        ...       ...         ...        ...       ...   ...
# 1037     98570     28394       96037        Zip        CA    CA
# 1038     98565     32143       96031        Zip        CA    CA
# 1039     98652     19038       96134        Zip        CA    CA
# 1040     98559     21965       96023        Zip        CA    CA
# 1041    399675     23737       91008        Zip        CA    CA
#
#                City                           Metro            CountyName  \
# 0     San Francisco   San Francisco-Oakland-Hayward  San Francisco County
# ...

# %%
school = pd.read_excel('California_highschool_ranking.xlsx')
school = school.drop(labels=[0,1,2],axis=0)
school = school.rename(columns=school.iloc[0])
school = school.drop(labels=[3],axis=0)
school
# Out:
#      Rank (2018-19)                                      School  \
# 4                 1                      Riverside STEM Academy
# 5                 2                     Whitney (Gretchen) High
# 6                 3              William & Marian Ghidotti High
# 7                 4                              Oxford Academy
# 8                 5                               Lynbrook High
# ...             ...                                         ...
# 2111           2108  Juvenile Hall (Endeavor/Voyager Secondary)
# 2112           2109              Captain John Continuation High
# 2113           2110                 Thomas E. Mathews Community
# 2114           2111                  Wellington M. Smith Junior
# 2115           2112    Elinor Lincoln Hickey Junior/Senior High
#
#                                              School URL  \
# 4     https://www.schooldigger.com/go/CA/schools/331...
# 5     https://www.schooldigger.com/go/CA/schools/016...
# ...

# %%
joint2= pd.merge(joint1,school,how = "inner",left_on=["City"],right_on=["City"])
joint2
# Out:
#        RegionID  SizeRank  RegionName RegionType StateName State  \
# 0         97564        13       94109        Zip        CA    CA
# 1         97564        13       94109        Zip        CA    CA
# 2         97564        13       94109        Zip        CA    CA
# 3         97564        13       94109        Zip        CA    CA
# 4         97564        13       94109        Zip        CA    CA
# ...         ...       ...         ...        ...       ...   ...
# 24109     98562     17885       96027        Zip        CA    CA
# 24110     98570     28394       96037        Zip        CA    CA
# 24111     98565     32143       96031        Zip        CA    CA
# 24112     98652     19038       96134        Zip        CA    CA
# 24113     98559     21965       96023        Zip        CA    CA
#
#                 City                          Metro            CountyName  \
# 0      San Francisco  San Francisco-Oakland-Hayward  San Francisco County
# ...
