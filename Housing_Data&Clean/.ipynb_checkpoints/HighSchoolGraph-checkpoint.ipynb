# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

from plotly import express as px
import numpy as np

# %%
homevalue = pd.read_csv("home_value_by_zipcode.csv")


homevalue



homevalue = homevalue[homevalue["State"] == "CA"]

homevalue.rename(columns = {"RegionName":"Zip"}, inplace=True)

#Check Column Names and their indexes
#i = 0
#for col_name in homevalue.columns: 
    #print(col_name,i)
    #i = i+1
    
    
Cali_homevalue_subset1 = homevalue.iloc[:,177:312]
Cali_homevalue_subset2 = homevalue.iloc[:,[2,5,6]]

Cali_homevalue = pd.concat([Cali_homevalue_subset2, Cali_homevalue_subset1], axis=1)

Cali_homevalue = Cali_homevalue.set_index(["Zip","State","City"])

Cali_homevalue = Cali_homevalue.stack()



Cali_homevalue = Cali_homevalue.reset_index()
Cali_homevalue = Cali_homevalue.rename(columns = {"level_3" :"Date",0:"Value"})

Cali_homevalue["Year"] = Cali_homevalue["Date"].str[:4].astype(int)





Cali_homevalue_combinedMonth = Cali_homevalue.groupby(["City","Zip","Year"])["Value"].mean()


Cali_homevalue_combinedMonth = Cali_homevalue_combinedMonth.reset_index()






def coef(data_group):
    x = data_group[["Year"]] # 2 brackets because X should be a df
    y = data_group["Value"]   # 1 bracket because y should be a series
    LR = LinearRegression()
    LR.fit(x, y)
    return LR.coef_[0]




coefs = Cali_homevalue_combinedMonth.groupby(["City","Zip"]).apply(coef)
coefs = coefs.reset_index()
coefs


coefs_sorted = coefs.sort_values([0], ascending=True)


coefs_sorted["Trend"]= (coefs_sorted[0]-np.mean(coefs_sorted[0]))/np.std(coefs_sorted[0])*10



zip_Geoinfo = pd.read_csv("us-zip-code-latitude-and-longitude.csv",sep=";") 

zip_Geoinfo["Zip"] = zip_Geoinfo["Zip"].astype(int)






coefs_sorted_Geoinfo = coefs_sorted.merge(zip_Geoinfo, on = "Zip")
#coefs_sorted_Geoinfo["try"] = np.where(coefs_sorted_Geoinfo.Trend > 0, 1, -1)



fig = px.scatter_mapbox(coefs_sorted_Geoinfo,
                            lat = "Latitude",
                            lon = "Longitude",
                            hover_name = "City_x",
                            color = "Trend",
                            zoom = 6,
                            height = 400,
                            mapbox_style = "stamen-terrain",
                            title = "California Housing Trend from 2010 to 2021")
fig.update_layout(margin={"r":0,"t":50,"l":0,"b":0})

fig.show()
# Out:
# <div>                            <div id="8965e7be-68ee-4b03-b8fc-9e93f912862f" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8965e7be-68ee-4b03-b8fc-9e93f912862f")) {                    Plotly.newPlot(                        "8965e7be-68ee-4b03-b8fc-9e93f912862f",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>Latitude=%{lat}<br>Longitude=%{lon}<br>Trend=%{marker.color}<extra></extra>", "hovertext": ["Big Sur", "Pescadero", "Port Costa", "Downieville", "Coulterville", "Hume", "Visalia", "Essex", "Alleghany", "Pescadero", "Paicines", "Keeler", "Darwin", "Fellows", "Annapolis", "El Centro", "Shoshone", "Hinkley", "Tobin", "Doyle", "Nubieber", "Mill Creek", "Earp", "Tuolumne", "Chilcoot", "Termo", "Needles", "Tulare", "Lockwood", "Boron", "Ravendale", "Big Bend", "Yermo", "New Pine Creek", "Long Barn", "Sonora", "Homewood Canyon-Valley Wells", "Jamestown", "Maricopa", "River Pines", "Macdoel", "Arbuckle", "Kernville", "Madeline", "Jacumba", "Borrego Springs", "Groveland", "Mc Kittrick", "Alturas", "Strawberry", "Dorris", "Tulelake", "Olancha", "Ridgecrest", "Ferndale", "Portola", "Randsburg", "Doyle", "Bodfish", "Wendel", "Lake Isabella", "Klamath", "Wofford Heights", "Mi Wuk Village", "Paynes Creek", "Wilseyville", "Canby", "Woodland", "Blythe", "Kettleman City", "Gerber", "Buttonwillow", "Mojave", "Korbel", "Bieber", "Loyalton", "Soulsbyville", "Fort Bidwell", "Dunsmuir", "Adin", "Coleville", "Stonyford", "Weldon", "Greenville", "Tehama", "Yreka", "Maxwell", "Grenada", "Mokelumne Hill", "Susanville", "Twain Harte", "Twentynine Palms", "Mill Creek", "Beckwourth", "Guinda", "Newberry Springs", "Columbia", "Coalinga", "Onyx", "Happy Camp", "Canyon Dam", "Valyermo", "Willow Creek", "Calipatria", "Edwards", "Mount Laguna", "Sierra City", "Hornbrook", "Inyokern", "Huron", "Myers Flat", "Samoa", "Coulterville", "Lost Hills", "Avenal", "Hume", "Greenville", "Redding", "Taft", "Likely", "Colusa", "Meadow Valley", "Cedarville", "Benton", "Twain", "Pope Valley", "West Point", "Montague", "Los Molinos", "Clipper Mills", "Whitethorn", "Arcata", "Camptonville", "Willows", "Corcoran", "Litchfield", "Graeagle", "Downieville", "Lookout", "McCloud", "Standish", "Vallecito", "Weed", "Red Bluff", "Etna", "Pioneer", "Jamestown", "Cantua Creek", "Williams", "Etna", "Chilcoot", "Taylorsville", "Seiad Valley", "Corning", "Desert Center", "Rio Dell", "Thermal", "Chester", "Fields Landing", "Armona", "Boulevard", "Westwood", "Lone Pine", "Caliente", "Eureka", "Barstow", "Janesville", "Thermal", "Pixley", "Fort Jones", "Kingsburg", "Quincy", "Mojave", "Clearlake", "Mokelumne Hill", "Le Grand", "Dinuba", "Big Oak Flat", "Earlimart", "Stratford", "Milford", "New Pine Creek", "Hamilton City", "Alpaugh", "Gazelle", "Klamath River", "San Andreas", "Soda Springs", "Etna", "Klamath River", "Forest Ranch", "Lake City", "Woodlake", "Calpine", "Independence", "Orange Cove", "Lamont", "Planada", "Forbestown", "Desert Hot Springs", "Sierraville", "McKinleyville", "Firebaugh", "Middletown", "Glennville", "Janesville", "Helendale", "Shasta Lake", "Clearlake Oaks", "Orosi", "McArthur", "Magalia", "San Joaquin", "Farmersville", "Nice", "Berry Creek", "Bakersfield", "Arnold", "Hanford", "Cutler", "Glencoe", "Riverdale", "Forbestown", "Lindsay", "French Gulch", "Willits", "Casmalia", "Tipton", "Covelo", "Porterville", "Arbuckle", "Coleville", "Somes Bar", "Richgrove", "Mc Farland", "Mountain Ranch", "Robbins", "Midpines", "Green Valley Lake", "Holtville", "Callahan", "Redway", "Dunlap", "Warner Springs", "Corning", "Twin Bridges", "Eureka", "Burney", "Ivanhoe", "Fresno", "Fortuna", "Wasco", "Strawberry Valley", "Dinuba", "Tranquillity", "Big Bar", "Exeter", "Bakersfield", "Cedarville", "Big Bear City", "Terra Be ...

# %%
def coef(data_group):
    x = data_group[["Year"]] # 2 brackets because X should be a df
    y = data_group["Value"]   # 1 bracket because y should be a series
    LR = LinearRegression()
    LR.fit(x, y)
    return LR.coef_[0]




coefs = Cali_homevalue_combinedMonth.groupby(["City","Zip"]).apply(coef)
coefs = coefs.reset_index()

coefs 
    

# California High School Data

Cali_school = pd.read_excel("California_highschool_ranking.xlsx")
Cali_school = Cali_school.iloc[3:,:]





Cali_school = Cali_school.rename(columns = Cali_school.iloc[0,:])

Cali_school = Cali_school.iloc[1:,:]
Cali_school = Cali_school.reset_index()
Cali_school = Cali_school.drop("index", axis = 1)
Cali_school["Zip"] = Cali_school["Zip"].astype(int)


# Access to top schools
#ToptenSchools = Cali_school.iloc[:300,:]

#ToptenSchools["Percent Asian"] = ToptenSchools["Percent Asian"].str[:-1].astype(float)

#ToptenSchools["Percent Asian"].mean()



zip_Geoinfo = pd.read_csv("us-zip-code-latitude-and-longitude.csv",sep=";") 

zip_Geoinfo["Zip"] = zip_Geoinfo["Zip"].astype(int)



Cali_School_Geoinfo = Cali_school.merge(zip_Geoinfo, on = "Zip")

Cali_School_Geoinfo["Latitude"] = Cali_School_Geoinfo["Latitude"].astype(float)
Cali_School_Geoinfo["Longitude"] = Cali_School_Geoinfo["Longitude"].astype(float)
Cali_School_Geoinfo["Rank (2018-19)"] = Cali_School_Geoinfo["Rank (2018-19)"].astype(float)




fig = px.scatter_mapbox(Cali_School_Geoinfo,
                            lat = "Latitude",
                            lon = "Longitude",
                            hover_name = "School",
                            color = "Rank (2018-19)",
                            zoom = 5,
                            height = 500,
                            mapbox_style = "stamen-terrain",
                            title = "California High School Ranking Map")
fig.update_layout(margin={"r":0,"t":50,"l":0,"b":0})

fig.show()
# Out:
# <div>                            <div id="ca946628-405e-4ba1-aec3-36129290def3" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ca946628-405e-4ba1-aec3-36129290def3")) {                    Plotly.newPlot(                        "ca946628-405e-4ba1-aec3-36129290def3",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>Latitude=%{lat}<br>Longitude=%{lon}<br>Rank (2018-19)=%{marker.color}<extra></extra>", "hovertext": ["Riverside STEM Academy", "John W. North High", "Abraham Lincoln Continuation", "Whitney (Gretchen) High", "Cerritos High", "Gahr (Richard) High", "ABC Secondary (Alternative)", "Tracy (Wilbur) High (Continuation)", "William & Marian Ghidotti High", "Nevada Union High", "North Point Academy", "Bitney Prep High", "Silver Springs High (Continuation)", "NU Technical High", "Oxford Academy", "Cypress High", "Lynbrook High", "Grossmont Middle College High", "Literacy First Charter", "Grossmont Secondary", "IDEA Center", "MERIT Academy", "Chaparral High", "Academy of the Canyons", "Valencia High", "Learning Post High (Alternative)", "Opportunities for Learning - Santa Clarita", "Mission View Public", "Campolindo High", "Middle College High", "Valley View Charter Prep", "Lincoln High", "Pacific Law Academy", "Humphreys College Academy of Business Law and Education", "Stagg Senior High", "Village Oaks High", "University High", "Technology High", "Credo High", "Pathways Charter", "Rancho Cotate High", "El Camino High", "Alameda Science and Technology Institute", "Alameda High", "Alameda Community Learning Center", "Encinal Junior/Senior High", "Nea Community Learning Center", "Island High (Continuation)", "Western Center Academy", "Alessandro High", "Aspire Community Day", "Dr. TJ Owens Gilroy Early College Academy", "Gilroy High", "Christopher High", "Mt. Madonna High", "Dr. Richard A. Vladovic Harbor Teacher Preparation Academy", "Phineas Banning Senior High", "Dan M. Issacs Avalon High", "River Valley Charter", "El Capitan High", "Pacific Collegiate Charter", "Santa Cruz High", "Santa Cruz County Community", "Santa Cruz County Court", "Mission San Jose High", "Miramonte High", "Monta Vista High", "Cupertino High", "Homestead High", "Granite Bay High", "University Preparatory", "Shasta Charter Academy", "Shasta High", "Stellar Charter", "North State Independence High", "Pioneer Continuation High", "Eunice Sato Academy of Math & Science", "Millikan High", "Beach High-Intensive Learning Program", "California Academy of Mathematics and Science", "Saratoga High", "Prospect High", "Canyon Crest Academy", "Torrey Pines High", "La Canada High", "Acalanes High", "University Preparatory Academy Charter", "Willow Glen High", "Academy of the Redwoods", "Alder Grove Charter School 2", "Eureka Senior High", "Eureka Community", "Zoe Barnum High", "Ocsa", "Nova Academy Early College High", "Santa Ana High", "Henry M. Gunn High", "Redwood Academy of Ukiah", "Ukiah High", "Accelerated Achievement Academy", "Ukiah Independent Study Academy", "South Valley High (Continuation)", "Mendocino County Community", "Troy High", "La Sierra High (Alternative)", "La Vista High (Continuation)", "Piedmont High", "Oakland Technical High", "Millennium High Alternative", "Hawthorne Math and Science Academy", "Da Vinci Design", "Hawthorne High", "Family First Charter", "Renaissance County Community", "Western Sierra Collegiate Academy", "Rocklin High", "Whitney High", "Rocklin Independent Charter Academy", "Victory High", "Palo Alto High", "Foothill High", "Monte Vista High", "San Ramon Valley High", "Del Amigo High (Continuation)", "Oak Park High", "Oak Park Independent", "Oak View High", "International Polytechnic High", "Ganesha High", "American High", "Washington High", "South Pasadena Senior High",  ...
