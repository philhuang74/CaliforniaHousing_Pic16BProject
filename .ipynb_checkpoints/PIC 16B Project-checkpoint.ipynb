# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

from plotly import express as px

# %%
homevalue = pd.read_csv("Zip_home.csv")


homevalue.shape



homevalue = homevalue[homevalue["State"] == "CA"]

homevalue.rename(columns = {"RegionName":"Zip"}, inplace=True)

#Check Column Names and their indexes
#i = 0
#for col_name in homevalue.columns: 
   # print(col_name,i)
    # i = i+1

    
Cali_homevalue_subset1 = homevalue.iloc[:,177:312]
Cali_homevalue_subset2 = homevalue.iloc[:,[2,5,6]]

Cali_homevalue = pd.concat([Cali_homevaue_subset2, Cali_homevaue_subset1], axis=1)

Cali_homevalue = Cali_homevalue.set_index(["Zip","State","City"])

Cali_homevalue = Cali_homevalue.stack()



Cali_homevalue = Cali_homevalue.reset_index()
Cali_homevalue = Cali_homevalue.rename(columns = {"level_3" :"Date",0:"Value"})

Cali_homevalue["Year"] = Cali_homevalue["Date"].str[:4].astype(int)




Cali_homevalue_combinedMonth = Cali_homevalue.groupby(["City","Zip","Year"])["Value"].mean()



Cali_homevalue_combinedMonth = Cali_homevalue_combinedMonth.reset_index()
Cali_homevalue_combinedMonth





def coef(data_group):
    x = data_group[["Year"]] # 2 brackets because X should be a df
    y = data_group["Value"]   # 1 bracket because y should be a series
    LR = LinearRegression()
    LR.fit(x, y)
    return LR.coef_[0]




coefs = Cali_homevalue_combinedMonth.groupby(["City","Zip"]).apply(coef)
coefs = coefs.reset_index()

coefs
# Out:
#               City    Zip             0
# 0           Acampo  95220  40515.582168
# 1            Acton  93510  29809.891026
# 2         Adelanto  92301  17125.610140
# 3             Adin  96006   6592.059149
# 4     Agoura Hills  91301  34711.716783
# ...            ...    ...           ...
# 1677     Yuba City  95993  18621.621212
# 1678       Yucaipa  92399  21767.608683
# 1679  Yucca Valley  92268  22206.712121
# 1680  Yucca Valley  92284  13416.338578
# 1681         Zenia  95595  31398.840278
#
# [1682 rows x 3 columns]

# %%
# California High School Data

Cali_school = pd.read_excel("California_highschool_ranking.xlsx")
Cali_school = Cali_school.iloc[3:,:]





Cali_school = Cali_school.rename(columns = Cali_school.iloc[0,:])

Cali_school = Cali_school.iloc[1:,:]
Cali_school = Cali_school.reset_index()
Cali_school = Cali_school.drop("index", axis = 1)
Cali_school["Zip"] = Cali_school["Zip"].astype(int)


# Access to top schools
#ToptenSchools = Cali_school.iloc[:300,:]

#ToptenSchools["Percent Asian"] = ToptenSchools["Percent Asian"].str[:-1].astype(float)

#ToptenSchools["Percent Asian"].mean()



zip_Geoinfo = pd.read_csv("us-zip-code-latitude-and-longitude.csv",sep=";") 

zip_Geoinfo["Zip"] = zip_Geoinfo["Zip"].astype(int)



Cali_School_Geoinfo = Cali_school.merge(zip_Geoinfo, on = "Zip")

Cali_School_Geoinfo["Latitude"] = Cali_School_Geoinfo["Latitude"].astype(float)
Cali_School_Geoinfo["Longitude"] = Cali_School_Geoinfo["Longitude"].astype(float)
Cali_School_Geoinfo["Rank (2018-19)"] = Cali_School_Geoinfo["Rank (2018-19)"].astype(float)




fig = px.scatter_mapbox(Cali_School_Geoinfo,
                            lat = "Latitude",
                            lon = "Longitude",
                            hover_name = "School",
                            color = "Rank (2018-19)",
                            zoom = 1,
                            height = 300,
                            mapbox_style = "stamen-terrain",
                            labels = {"ABC"},
                            title = "a")
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})

fig.show()
# Out:
# <div>                            <div id="b807d1df-f162-4d3a-bd12-de7eff181921" class="plotly-graph-div" style="height:300px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b807d1df-f162-4d3a-bd12-de7eff181921")) {                    Plotly.newPlot(                        "b807d1df-f162-4d3a-bd12-de7eff181921",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>Latitude=%{lat}<br>Longitude=%{lon}<br>Rank (2018-19)=%{marker.color}<extra></extra>", "hovertext": ["Riverside STEM Academy", "John W. North High", "Abraham Lincoln Continuation", "Whitney (Gretchen) High", "Cerritos High", "Gahr (Richard) High", "ABC Secondary (Alternative)", "Tracy (Wilbur) High (Continuation)", "William & Marian Ghidotti High", "Nevada Union High", "North Point Academy", "Bitney Prep High", "Silver Springs High (Continuation)", "NU Technical High", "Oxford Academy", "Cypress High", "Lynbrook High", "Grossmont Middle College High", "Literacy First Charter", "Grossmont Secondary", "IDEA Center", "MERIT Academy", "Chaparral High", "Academy of the Canyons", "Valencia High", "Learning Post High (Alternative)", "Opportunities for Learning - Santa Clarita", "Mission View Public", "Campolindo High", "Middle College High", "Valley View Charter Prep", "Lincoln High", "Pacific Law Academy", "Humphreys College Academy of Business Law and Education", "Stagg Senior High", "Village Oaks High", "University High", "Technology High", "Credo High", "Pathways Charter", "Rancho Cotate High", "El Camino High", "Alameda Science and Technology Institute", "Alameda High", "Alameda Community Learning Center", "Encinal Junior/Senior High", "Nea Community Learning Center", "Island High (Continuation)", "Western Center Academy", "Alessandro High", "Aspire Community Day", "Dr. TJ Owens Gilroy Early College Academy", "Gilroy High", "Christopher High", "Mt. Madonna High", "Dr. Richard A. Vladovic Harbor Teacher Preparation Academy", "Phineas Banning Senior High", "Dan M. Issacs Avalon High", "River Valley Charter", "El Capitan High", "Pacific Collegiate Charter", "Santa Cruz High", "Santa Cruz County Community", "Santa Cruz County Court", "Mission San Jose High", "Miramonte High", "Monta Vista High", "Cupertino High", "Homestead High", "Granite Bay High", "University Preparatory", "Shasta Charter Academy", "Shasta High", "Stellar Charter", "North State Independence High", "Pioneer Continuation High", "Eunice Sato Academy of Math & Science", "Millikan High", "Beach High-Intensive Learning Program", "California Academy of Mathematics and Science", "Saratoga High", "Prospect High", "Canyon Crest Academy", "Torrey Pines High", "La Canada High", "Acalanes High", "University Preparatory Academy Charter", "Willow Glen High", "Academy of the Redwoods", "Alder Grove Charter School 2", "Eureka Senior High", "Eureka Community", "Zoe Barnum High", "Ocsa", "Nova Academy Early College High", "Santa Ana High", "Henry M. Gunn High", "Redwood Academy of Ukiah", "Ukiah High", "Accelerated Achievement Academy", "Ukiah Independent Study Academy", "South Valley High (Continuation)", "Mendocino County Community", "Troy High", "La Sierra High (Alternative)", "La Vista High (Continuation)", "Piedmont High", "Oakland Technical High", "Millennium High Alternative", "Hawthorne Math and Science Academy", "Da Vinci Design", "Hawthorne High", "Family First Charter", "Renaissance County Community", "Western Sierra Collegiate Academy", "Rocklin High", "Whitney High", "Rocklin Independent Charter Academy", "Victory High", "Palo Alto High", "Foothill High", "Monte Vista High", "San Ramon Valley High", "Del Amigo High (Continuation)", "Oak Park High", "Oak Park Independent", "Oak View High", "International Polytechnic High", "Ganesha High", "American High", "Washington High", "South Pasadena Senior High",  ...

# %%
## lR




def coef(data_group):
    x = data_group[["Date"]] # 2 brackets because X should be a df
    y = data_group["Value"]   # 1 bracket because y should be a series
    LR = LinearRegression()
    LR.fit(x, y)
    return LR.coef_[0]




coefs = Cali_homevalue.groupby(["State", "City","Zip"]).apply(coef)

coefs = coefs.reset_index()




(coefs[0] > 1).mean()




Cali_homevalue["Year"] = pd.to_datetime(Cali_homevalue["Year"])


Cali_homevalue


Cali_homevalue.groupby(["State", "City","Zip"]).apply(coef)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-95-16e29a1eb313> in <module>
#      12
#      13
# ---> 14 coefs = Cali_homevalue.groupby(["State", "City","Zip"]).apply(coef)
#      15
#      16 coefs = coefs.reset_index()
#
# /opt/anaconda3/envs/PIC16B/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#     892         with option_context("mode.chained_assignment", None):
#     893             try:
# --> 894                 result = self._python_apply_general(f, self._selected_obj)
#     895             except TypeError:
#     896                 # gh-20949
#
# /opt/anaconda3/envs/PIC16B/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f, data)
#     926             data after applying f
#     927         """
# --> 928         keys, values, mutated = self.grouper.apply(f, data, self.axis)
#     929
#     930         return self._wrap_applied_output(
#
# /opt/anaconda3/envs/PIC16B/lib/python3.7/site-packages/pandas/core/groupby/ops.py in apply(self, f, data, axis)
#     236             # group might be modified
#     237             group_axes = group.axes
# --> 238             res = f(group)
#     239             if not _is_indexed_like(res, group_axes, axis):
#     240                 mutated = True
#
# <ipython-input-95-16e29a1eb313> in coef(data_group)
#       6     y = data_group["Value"]   # 1 bracket because y should be a series
#       7     LR = LinearRegression()
# ----> 8     LR.fit(x, y)
#       9     return LR.coef_[0]
#      10
#
# /opt/anaconda3/envs/PIC16B/lib/python3.7/site-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     517
#     518         X, y = self._validate_data(X, y, accept_sparse=accept_sparse,
# --> 519                                    y_numeric=True, multi_output=True)
#     520
#     521         if sample_weight is not None:
#
# /opt/anaconda3/envs/PIC16B/lib/python3.7/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# --> 433                 X, y = check_X_y(X, y, **check_params)
#     434             out = X, y
#     435
#
# /opt/anaconda3/envs/PIC16B/lib/python3.7/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# /opt/anaconda3/envs/PIC16B/lib/python3.7/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     819                     ensure_min_samples=ensure_min_samples,
#     820                     ensure_min_features=ensure_min_features,
# --> 821                     estimator=estimator)
#     822     if multi_output:
#     823         y = check_array(y, accept_sparse='csr', force_all_finite=True,
#
# /opt/anaconda3/envs/PIC16B/lib/python3.7/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# /opt/anaconda3/envs/PIC16B/lib/python3.7/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     614                     array = array.astype(dtype, casting="unsafe", copy=False)
#     615                 else:
# --> 616                     array = np.asarray(array, order=order, dtype=dtype)
#     617             except ComplexWarning as complex_warning:
#     618                 raise ValueError("Complex data not supported\n"
#
# /opt/anaconda3/envs/PIC16B/lib/python3.7/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# /opt/anaconda3/envs/PIC16B/lib/python3.7/site-packages/pandas/core/generic.py in __array__(self, dtype)
#    1897
#    1898     def __array__(self, dtype=None) -> np.ndarray:
# -> 1899         return np.asarray(self._values, dtype=dtype)
#    1900
#    1901     def __array_wrap__(
#
# /opt/anaconda3/envs/PIC16B/lib/python3.7/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# ValueError: could not convert string to float: '2010-01-31'

# %%
fig.show()
# Out:
# <div>                            <div id="14966153-53ba-495e-9fcc-c4b1c032a96d" class="plotly-graph-div" style="height:300px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("14966153-53ba-495e-9fcc-c4b1c032a96d")) {                    Plotly.newPlot(                        "14966153-53ba-495e-9fcc-c4b1c032a96d",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>Rank (2018-19)=1<br>Latitude=%{lat}<br>Longitude=%{lon}<extra></extra>", "hovertext": ["Riverside STEM Academy"], "lat": [33.978965], "legendgroup": "1", "lon": [-117.33646], "marker": {"color": "#636efa"}, "mode": "markers", "name": "1", "showlegend": true, "subplot": "mapbox", "type": "scattermapbox"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Rank (2018-19)=1345<br>Latitude=%{lat}<br>Longitude=%{lon}<extra></extra>", "hovertext": ["John W. North High"], "lat": [33.978965], "legendgroup": "1345", "lon": [-117.33646], "marker": {"color": "#EF553B"}, "mode": "markers", "name": "1345", "showlegend": true, "subplot": "mapbox", "type": "scattermapbox"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Rank (2018-19)=1686<br>Latitude=%{lat}<br>Longitude=%{lon}<extra></extra>", "hovertext": ["Abraham Lincoln Continuation"], "lat": [33.978965], "legendgroup": "1686", "lon": [-117.33646], "marker": {"color": "#00cc96"}, "mode": "markers", "name": "1686", "showlegend": true, "subplot": "mapbox", "type": "scattermapbox"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Rank (2018-19)=2<br>Latitude=%{lat}<br>Longitude=%{lon}<extra></extra>", "hovertext": ["Whitney (Gretchen) High"], "lat": [33.868314], "legendgroup": "2", "lon": [-118.06754], "marker": {"color": "#ab63fa"}, "mode": "markers", "name": "2", "showlegend": true, "subplot": "mapbox", "type": "scattermapbox"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Rank (2018-19)=104<br>Latitude=%{lat}<br>Longitude=%{lon}<extra></extra>", "hovertext": ["Cerritos High"], "lat": [33.868314], "legendgroup": "104", "lon": [-118.06754], "marker": {"color": "#FFA15A"}, "mode": "markers", "name": "104", "showlegend": true, "subplot": "mapbox", "type": "scattermapbox"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Rank (2018-19)=403<br>Latitude=%{lat}<br>Longitude=%{lon}<extra></extra>", "hovertext": ["Gahr (Richard) High"], "lat": [33.868314], "legendgroup": "403", "lon": [-118.06754], "marker": {"color": "#19d3f3"}, "mode": "markers", "name": "403", "showlegend": true, "subplot": "mapbox", "type": "scattermapbox"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Rank (2018-19)=1604<br>Latitude=%{lat}<br>Longitude=%{lon}<extra></extra>", "hovertext": ["ABC Secondary (Alternative)"], "lat": [33.868314], "legendgroup": "1604", "lon": [-118.06754], "marker": {"color": "#FF6692"}, "mode": "markers", "name": "1604", "showlegend": true, "subplot": "mapbox", "type": "scattermapbox"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Rank (2018-19)=1642<br>Latitude=%{lat}<br>Longitude=%{lon}<extra></extra>", "hovertext": ["Tracy (Wilbur) High (Continuation)"], "lat": [33.868314], "legendgroup": "1642", "lon": [-118.06754], "marker": {"color": "#B6E880"}, "mode": "markers", "name": "1642", "showlegend": true, "subplot": "mapbox", "type": "scattermapbox"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Rank (2018-19)=3<br>Latitude=%{lat}<br>Longitude=%{lon}<extra></extra>", "hovertext": ["William & Marian Ghidotti High"], "lat": [39.202725], "legendgroup": "3", "lon": [-121.02076], "marker": {"color": "#FF97FF"}, "mode": "markers", "name": "3", "showlegend": true, "subplot": "mapbox", "type": "scattermapbox"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Rank (2018-19)=308<br>Latitude=%{lat}<br>Longitude=%{lon}<extra></extra>", "hovertext": ["Nevada Union High"], "lat": [39.202725], "legendgroup": "308", "lon": [-121.02076], "marker": {"color ...

# %%
Cali_School_Geoinfo
# Out:
#      Rank (2018-19)                         School  \
# 0                 1         Riverside STEM Academy
# 1              1345             John W. North High
# 2              1686   Abraham Lincoln Continuation
# 3                 2        Whitney (Gretchen) High
# 4               104                  Cerritos High
# ...             ...                            ...
# 2090           2036           N.A. Chaderjian High
# 2091           2055              Johanna Boss High
# 2092           2038    Chesnut High (Continuation)
# 2093           2083                    Lovell High
# 2094           2099  Life Learning Academy Charter
#
#                                              School URL  \
# 0     https://www.schooldigger.com/go/CA/schools/331...
# 1     https://www.schooldigger.com/go/CA/schools/331...
# 2     https://www.schooldigger.com/go/CA/schools/331...
# 3     https://www.schooldigger.com/go/CA/schools/016...
# 4     https://www.schooldigger.com/go/CA/schools/016...
# ...                                                 ...
# 2090  https://www.schooldigger.com/go/CA/schools/014...
# 2091  https://www.schooldigger.com/go/CA/schools/014...
# 2092  https://www.schooldigger.com/go/CA/schools/091...
# 2093  https://www.schooldigger.com/go/CA/schools/103...
# 2094  https://www.schooldigger.com/go/CA/schools/344...
#
#                                                District  \
# 0                                     Riverside Unified
# 1                                     Riverside Unified
# 2                                     Riverside Unified
# 3                                           ABC Unified
# 4                                           ABC Unified
# ...                                                 ...
# 2090  California Education Authority (CEA) Headquarters
# 2091  California Education Authority (CEA) Headquarters
# 2092                             Coalinga-Huron Unified
# 2093                         Cutler-Orosi Joint Unified
# 2094                              San Francisco Unified
#
#                                            District URL  \
# 0     https://www.schooldigger.com/go/CA/district/33...
# 1     https://www.schooldigger.com/go/CA/district/33...
# 2     https://www.schooldigger.com/go/CA/district/33...
# 3     https://www.schooldigger.com/go/CA/district/01...
# 4     https://www.schooldigger.com/go/CA/district/01...
# ...                                                 ...
# 2090  https://www.schooldigger.com/go/CA/district/01...
# 2091  https://www.schooldigger.com/go/CA/district/01...
# 2092  https://www.schooldigger.com/go/CA/district/09...
# 2093  https://www.schooldigger.com/go/CA/district/10...
# 2094  https://www.schooldigger.com/go/CA/district/34...
#
#                              Address         City_x  \
# 0                4466 Mt.Vernon Ave.      Riverside
# 1                  1550 W. Third St.      Riverside
# 2                 4341 Victoria Ave.      Riverside
# 3               16800 Shoemaker Ave.       Cerritos
# 4                 12500 E. 183rd St.       Cerritos
# ...                              ...            ...
# 2090           7650 S. Newcastle Rd.       Stockton
# 2091           7650 S. Newcastle Rd.       Stockton
# 2092                    16673 Palmer          Huron
# 2093                  12724 Ave. 392         Cutler
# 2094  651 Eighth St. Bldg. 229 Treas  San Francisco
#
#                                                City URL    Zip  \
# 0     https://www.schooldigger.com/go/CA/city/Rivers...  92507
# 1     https://www.schooldigger.com/go/CA/city/Rivers...  92507
# 2     https://www.schooldigger.com/go/CA/city/Rivers...  92507
# 3     https://www.schooldigger.com/go/CA/city/Cerrit...  90703
# 4     https://www.schooldigger.com/go/CA/city/Cerrit...  90703
# ...                                                 ...    ...
# 2090  https://www.schooldigger.com/go/CA/city/Stockt...  95213
# 2091  https://www.schooldigger.com/go/CA/city/Stockt...  95213
# 2092  https://www.schooldigger.com/go/CA/city/Huron/...  93234
# 2093  https://www.schooldigger.com/go/CA/city/Cutler...  93615
# 2094  https://www.schooldigger.com/go/CA/city/San+Fr...  94130
#
#                     County  ... Rank (2017-18) Rank Change from (2017-18)  \
# 0         Riverside County  ...             23                         22
# 1         Riverside County  ...           1197                       -148
# 2         Riverside County  ...           1828                        142
# 3       Los Angeles County  ...              2                          0
# 4       Los Angeles County  ...             74                        -30
# ...                    ...  ...            ...                        ...
# 2090    San Joaquin County  ...           1777                       -259
# 2091    San Joaquin County  ...           1918                       -137
# 2092         Fresno County  ...            NaN                        NaN
# 2093         Tulare County  ...           1670                       -413
# 2094  San Francisco County  ...            NaN                        NaN
#
#      SchoolDigger Star Rating         City_y State   Latitude   Longitude  \
# 0                           5      Riverside    CA  33.978965 -117.336460
# 1                           2      Riverside    CA  33.978965 -117.336460
# 2                           1      Riverside    CA  33.978965 -117.336460
# 3                           5       Cerritos    CA  33.868314 -118.067540
# 4                           5       Cerritos    CA  33.868314 -118.067540
# ...                       ...            ...   ...        ...         ...
# 2090                        0       Stockton    CA  37.904777 -121.226782
# 2091                        0       Stockton    CA  37.904777 -121.226782
# 2092                        0          Huron    CA  36.209815 -120.084700
# 2093                        0         Cutler    CA  36.506019 -119.286600
# 2094                        0  San Francisco    CA  37.819423 -122.369660
#
#      Timezone Daylight savings time flag               geopoint
# 0          -8                          1   33.978965,-117.33646
# 1          -8                          1   33.978965,-117.33646
# 2          -8                          1   33.978965,-117.33646
# 3          -8                          1   33.868314,-118.06754
# 4          -8                          1   33.868314,-118.06754
# ...       ...                        ...                    ...
# 2090       -8                          1  37.904777,-121.226782
# 2091       -8                          1  37.904777,-121.226782
# 2092       -8                          1    36.209815,-120.0847
# 2093       -8                          1    36.506019,-119.2866
# 2094       -8                          1   37.819423,-122.36966
#
# [2095 rows x 40 columns]
